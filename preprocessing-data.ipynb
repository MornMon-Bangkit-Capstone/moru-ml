# %%
import numpy as np
import pandas as pd
import json
import re
import csv
from tqdm import tqdm

# %%
cek = pd.read_csv('data/BX-CSV-Dump/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# Out:
# /tmp/ipykernel_5308/3577112586.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cek = pd.read_csv('data/BX-CSV-Dump/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
# Skipping line 180189: expected 8 fields, saw 9
# Skipping line 185738: expected 8 fields, saw 9
#
# Skipping line 209388: expected 8 fields, saw 9
# Skipping line 220626: expected 8 fields, saw 9
# Skipping line 227933: expected 8 fields, saw 11
# Skipping line 228957: expected 8 fields, saw 10
# Skipping line 245933: expected 8 fields, saw 9
# Skipping line 251296: expected 8 fields, saw 9
# Skipping line 259941: expected 8 fields, saw 9
# Skipping line 261529: expected 8 fields, saw 9
#
# /tmp/ipykernel_5308/3577112586.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   cek = pd.read_csv('data/BX-CSV-Dump/BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")

# %%
cek
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]

# %%
cek2 = pd.read_csv('data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
cek2
# Out:
# /tmp/ipykernel_5308/400389786.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   cek2 = pd.read_csv('data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
result = cek2[cek2["Book-Rating"] != 0]
result
# Out:
#          User-ID         ISBN  Book-Rating
# 1         276726   0155061224            5
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# 6         276736   3257224281            8
# 7         276737   0600570967            6
# ...          ...          ...          ...
# 1149773   276704   0806917695            5
# 1149775   276704   1563526298            9
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [433671 rows x 3 columns]

# %%
dupli = cek.duplicated().sum()

# %%
dupli
# Out:
# 0

# %%
pd.set_option('display.max_colwidth', 300)

data = []

with open("data/booksummaries.txt", 'r') as f:
    reader = csv.reader(f, dialect='excel-tab')
    for row in tqdm(reader):
        data.append(row)
# Out:
# 16559it [00:00, 22562.71it/s]

# %%
book_index = []
book_id = []
book_author = []
book_name = []
summary = []
genre = []
a = 1
for i in tqdm(data):
    book_index.append(a)
    a = a+1
    book_id.append(i[0])
    book_name.append(i[2])
    book_author.append(i[3])
    genre.append(i[5])
    summary.append(i[6])

df = pd.DataFrame({'Index': book_index, 'ID': book_id, 'BookTitle': book_name, 'Author': book_author,
                       'Genre': genre, 'Summary': summary})
# Out:
# 100%|██████████| 16559/16559 [00:00<00:00, 207023.48it/s]

# %%
df.isna().sum()

df = df.drop(df[df['Genre'] == ''].index)
df = df.drop(df[df['Summary'] == ''].index)


genres_cleaned = []
for i in df['Genre']:
    genres_cleaned.append(list(json.loads(i).values()))
df['Genres'] = genres_cleaned

# %%
df.drop(['Genre'], axis=1, inplace=True)

# %%
df
# Out:
#        Index        ID                       BookTitle                Author  \
# 0          1       620                     Animal Farm         George Orwell
# 1          2       843              A Clockwork Orange       Anthony Burgess
# 2          3       986                      The Plague          Albert Camus
# 4          5      2080            A Fire Upon the Deep          Vernor Vinge
# 5          6      2152  All Quiet on the Western Front  Erich Maria Remarque
# ...      ...       ...                             ...                   ...
# 16549  16550  36372465                  The Third Lynx          Timothy Zahn
# 16551  16552  36534061                  Remote Control            Andy McNab
# 16555  16556  37054020               Transfer of Power           Vince Flynn
# 16556  16557  37122323                         Decoded                 Jay-Z
# 16558  16559  37159503                       Poor Folk    Fyodor Dostoyevsky
#
#                                                                                                                                                                                                                                                                                                            Summary  \
# 0       Old Major, the old boar on the Manor Farm, calls the animals on the farm for a meeting, where he compares the humans to parasites and teaches the animals a revolutionary song, 'Beasts of England'. When Major dies, two young pigs, Snowball and Napoleon, assume command and turn his dream into a p...
# 1       Alex, a teenager living in near-future England, leads his gang on nightly orgies of opportunistic, random "ultra-violence." Alex's friends ("droogs" in the novel's Anglo-Russian slang, Nadsat) are: Dim, a slow-witted bruiser who is the gang's muscle; Georgie, an ambitious second-in-command; and...
# 2       The text of The Plague is divided into five parts. In the town of Oran, thousands of rats, initially unnoticed by the populace, begin to die in the streets. A hysteria develops soon afterward, causing the local newspapers to report the incident. Authorities responding to public pressure order t...
# 4       The novel posits that space around the Milky Way is divided into concentric layers called Zones, each being constrained by different laws of physics and each allowing for different degrees of biological and technological advancement. The innermost, the "Unthinking Depths", surrounds the galacti...
# 5       The book tells the story of Paul Bäumer, a German soldier who—urged on by his school teacher—joins the German army shortly after the start of World War I. Bäumer arrives at the Western Front with his friends and schoolmates (Tjaden, Müller, Kropp and a number of other characters). There they me...
# ...                                                                                                                                                                                                                                                                                                            ...
# 16549   The story starts with former government agent, Frank Compton, meeting a young man who drops dead at his feet. Compton finds a ticket to a strange, interstellar train called the Quadrail. During Compton's ride on the Quadrail he falls asleep, and wakes up in the custody of the spiders, the opera...
# 16551   The series follows the character of Nick Stone, an ex-military man who previously worked for the SAS, British Intelligence, and an American agency. Stone now works as a paid mercenary, willing to work in even the most difficult circumstances. The series has Stone dealing with assassination, pol...
# 16555   The reader first meets Rapp while he is doing a covert operation in Iran and he discovers a possible terrorist attack planned for the nations capital to happen in the near future. Meanwhile in Washington, D.C., Anna Reilly is starting her first day as a White House correspondent for NBC. It als...
# 16556   The book follows very rough chronological order, while switching from current stories to his story of growing up in the Marcy projects. The autobiographical portion focuses on not only his story of drug dealing, fights, and the beginnings in rap, but also his reflections on those times in his l...
# 16558   Makar Devushkin and Varvara Dobroselova are second cousins twice-removed and live across from each other on the same street in terrible apartments. Devushkin's, for example, is merely a portioned-off section of the kitchen, and he lives with several other tenants, such as the Gorshkovs, whose s...
#
#                                                                                                 Genres
# 0                          [Roman à clef, Satire, Children's literature, Speculative fiction, Fiction]
# 1      [Science Fiction, Novella, Speculative fiction, Utopian and dystopian fiction, Satire, Fiction]
# 2                                                  [Existentialism, Fiction, Absurdist fiction, Novel]
# 4                       [Hard science fiction, Science Fiction, Speculative fiction, Fantasy, Fiction]
# 5                                                                            [War novel, Roman à clef]
# ...                                                                                                ...
# 16549                                                                                [Science Fiction]
# 16551                                                                    [Thriller, Fiction, Suspense]
# 16555                                                                              [Thriller, Fiction]
# 16556                                                                                  [Autobiography]
# 16558                                                          [Epistolary novel, Speculative fiction]
#
# [12841 rows x 6 columns]

# %%
df.rename(columns={'BookTitle': 'Book-Title'}, inplace=True)

# %%
df_fix = pd.merge(cek, df, on='Book-Title')

# %%
df_fix.head()
# Out:
#           ISBN             Book-Title         Book-Author Year-Of-Publication  \
# 0   0440234743          The Testament        John Grisham                1999
# 14  0345402871               Airframe    Michael Crichton                1997
# 19  0345417623               Timeline    MICHAEL CRICHTON                2000
# 26  0446310786  To Kill a Mockingbird          Harper Lee                1988
# 34  0060168013         Pigs in Heaven  Barbara Kingsolver                1993
#
#                      Publisher  \
# 0                         Dell
# 14            Ballantine Books
# 19            Ballantine Books
# 26  Little Brown &amp; Company
# 34               Harpercollins
#
#                                                      Image-URL-S  \
# 0   http://images.amazon.com/images/P/0440234743.01.THUMBZZZ.jpg
# 14  http://images.amazon.com/images/P/0345402871.01.THUMBZZZ.jpg
# 19  http://images.amazon.com/images/P/0345417623.01.THUMBZZZ.jpg
# 26  http://images.amazon.com/images/P/0446310786.01.THUMBZZZ.jpg
# 34  http://images.amazon.com/images/P/0060168013.01.THUMBZZZ.jpg
#
#                                                      Image-URL-M  \
# 0   http://images.amazon.com/images/P/0440234743.01.MZZZZZZZ.jpg
# 14  http://images.amazon.com/images/P/0345402871.01.MZZZZZZZ.jpg
# 19  http://images.amazon.com/images/P/0345417623.01.MZZZZZZZ.jpg
# 26  http://images.amazon.com/images/P/0446310786.01.MZZZZZZZ.jpg
# 34  http://images.amazon.com/images/P/0060168013.01.MZZZZZZZ.jpg
#
#                                                      Image-URL-L  Index  \
# 0   http://images.amazon.com/images/P/0440234743.01.LZZZZZZZ.jpg   2832
# 14  http://images.amazon.com/images/P/0345402871.01.LZZZZZZZ.jpg   1944
# 19  http://images.amazon.com/images/P/0345417623.01.LZZZZZZZ.jpg   2358
# 26  http://images.amazon.com/images/P/0446310786.01.LZZZZZZZ.jpg    309
# 34  http://images.amazon.com/images/P/0060168013.01.LZZZZZZZ.jpg   2884
#
#          ID              Author  \
# 0   1703697        John Grisham
# 14   999996    Michael Crichton
# 19  1298672    Michael Crichton
# 26    73408          Harper Lee
# 34  1761825  Barbara Kingsolver
#
#                                                                                                                                                                                                                                                                                                         Summary  \
# 0    Troy Phelan, an eccentric elderly billionaire, commits suicide minutes after leaving his vast fortune to an illegitimate daughter, Rachel Lane, instead of his six children by three marriages. His reason is revulsion over years of fighting with, and embarrassment from, his family, as well as the...
# 14   The novel opens aboard Hong Kong-based Transpacific Airlines Flight 545, a Norton Aircraft-manufactured N-22 wide-body aircraft, flying from Hong Kong to Denver. An incident occurs on board the plane about a half-hour west of the California coast and the pilot requests an emergency landing at L...
# 19   In the middle of the New Mexico desert, a vacationing couple comes across an ill man wandering miles from town. They find the man, Joe Traub, is a physicist and an employee of a company called ITC. However, ITC's headquarters are mysteriously far from where Traub was found. Traub soon dies of a...
# 26   The book opens with the Finch family's ancestor, Simon Finch, a Cornish Methodist fleeing religious intolerance in England, settling in Alabama, becoming wealthy and, contrary to his religious beliefs, buying several slaves. The main story takes place during three years of the Great Depression ...
# 34   This novel begins two years after the events of Barbara Kingsolver's first novel, The Bean Trees. Taylor and Turtle are visiting the Hoover Dam when Turtle sees a man fall down a spillway. Because of Taylor's unwavering faith that Turtle is telling the truth, a search is conducted and a man's l...
#
#                                   Genres
# 0          [Thriller, Fiction, Suspense]
# 14              [Science Fiction, Novel]
# 19  [Science Fiction, Fiction, Suspense]
# 26                             [Fiction]
# 34                      [Fiction, Novel]

# %%
df_fix.drop_duplicates(subset=['Book-Title'], inplace=True)

# %%
df_fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5067 entries, 0 to 12089
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ISBN                 5067 non-null   object
#  1   Book-Title           5067 non-null   object
#  2   Book-Author          5067 non-null   object
#  3   Year-Of-Publication  5067 non-null   object
#  4   Publisher            5067 non-null   object
#  5   Image-URL-S          5067 non-null   object
#  6   Image-URL-M          5067 non-null   object
#  7   Image-URL-L          5067 non-null   object
#  8   Index                5067 non-null   int64
#  9   ID                   5067 non-null   object
#  10  Author               5067 non-null   object
#  11  Summary              5067 non-null   object
#  12  Genres               5067 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 554.2+ KB

# %%
df_ratings = pd.read_csv('data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# Out:
# /tmp/ipykernel_5308/1792764400.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_ratings = pd.read_csv('data/BX-CSV-Dump/BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")

# %%
df_ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
df_ratings = df_ratings[df_ratings['ISBN'].isin(df_fix['ISBN'])]

# %%
df_ratings
# Out:
#          User-ID        ISBN  Book-Rating
# 10        276746  0425115801            0
# 16        276747  0060517794            9
# 29        276755  0451166892            5
# 33        276762  0380711524            5
# 34        276762  0451167317            0
# ...          ...         ...          ...
# 1149696   276688  0446604666            0
# 1149697   276688  044661193X            7
# 1149751   276690  0440439884            0
# 1149766   276704  0441007813            0
# 1149771   276704  0743211383            7
#
# [91101 rows x 3 columns]

# %%
avg_rating = df_ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
avg_rating
# Out:
#             ISBN  Book-Rating
# 0     000160418X          3.5
# 1     0001841572          2.5
# 2     0002222590          0.0
# 3     0002223589          0.0
# 4     0002224682          0.0
# ...          ...          ...
# 5053  B000069F44          0.0
# 5054  B00007MAM9          0.0
# 5055  B0000A2U93          3.5
# 5056  B0000AZW79          9.0
# 5057  B00017IWGQ          0.0
#
# [5058 rows x 2 columns]

# %%
count_rating = df_ratings.groupby('ISBN')['Book-Rating'].count().reset_index()
count_rating
# Out:
#             ISBN  Book-Rating
# 0     000160418X            2
# 1     0001841572            2
# 2     0002222590            1
# 3     0002223589            1
# 4     0002224682            2
# ...          ...          ...
# 5053  B000069F44            1
# 5054  B00007MAM9            1
# 5055  B0000A2U93            2
# 5056  B0000AZW79            1
# 5057  B00017IWGQ            1
#
# [5058 rows x 2 columns]

# %%
df_ratings = pd.merge(df_ratings, avg_rating, on='ISBN')

# %%
df_ratings
# Out:
#        User-ID        ISBN  Book-Rating_x  Book-Rating_y
# 0       276746  0425115801              0       2.529851
# 1       277427  0425115801              0       2.529851
# 2         1660  0425115801              0       2.529851
# 3         2288  0425115801             10       2.529851
# 4         4551  0425115801              8       2.529851
# ...        ...         ...            ...            ...
# 91096   275970  0670036390              0       0.000000
# 91097   275970  0749312270              0       0.000000
# 91098   275970  1400031176              0       0.000000
# 91099   276213  0345292901              0       0.000000
# 91100   276213  0449221008              0       0.000000
#
# [91101 rows x 4 columns]

# %%
res0 = df_ratings[df_ratings['Book-Rating_y'] == 0]
res0
# Out:
#        User-ID        ISBN  Book-Rating_x  Book-Rating_y
# 1805    276925  0754000117              0            0.0
# 1806    134434  0754000117              0            0.0
# 13482   277427  1557733090              0            0.0
# 13483    40012  1557733090              0            0.0
# 13484    76352  1557733090              0            0.0
# ...        ...         ...            ...            ...
# 91096   275970  0670036390              0            0.0
# 91097   275970  0749312270              0            0.0
# 91098   275970  1400031176              0            0.0
# 91099   276213  0345292901              0            0.0
# 91100   276213  0449221008              0            0.0
#
# [2245 rows x 4 columns]

# %%
resna0 = df_ratings[df_ratings['Book-Rating_y'] != 0]
resna0
# Out:
#        User-ID        ISBN  Book-Rating_x  Book-Rating_y
# 0       276746  0425115801              0       2.529851
# 1       277427  0425115801              0       2.529851
# 2         1660  0425115801              0       2.529851
# 3         2288  0425115801             10       2.529851
# 4         4551  0425115801              8       2.529851
# ...        ...         ...            ...            ...
# 91079   273976  0786866705              5       5.000000
# 91083   274186  8466302948              1       1.000000
# 91084   274199  0140072799              9       9.000000
# 91094   275825  0689822855              7       7.500000
# 91095   276560  0689822855              8       7.500000
#
# [88856 rows x 4 columns]

# %%
resna0Jbooks = df_ratings[df_ratings['Book-Rating_y'] != 0]
resna0
# Out:
#        User-ID        ISBN  Book-Rating_x  Book-Rating_y
# 0       276746  0425115801              0       2.529851
# 1       277427  0425115801              0       2.529851
# 2         1660  0425115801              0       2.529851
# 3         2288  0425115801             10       2.529851
# 4         4551  0425115801              8       2.529851
# ...        ...         ...            ...            ...
# 91079   273976  0786866705              5       5.000000
# 91083   274186  8466302948              1       1.000000
# 91084   274199  0140072799              9       9.000000
# 91094   275825  0689822855              7       7.500000
# 91095   276560  0689822855              8       7.500000
#
# [88856 rows x 4 columns]

# %%
res0Jbooks = avg_rating[avg_rating['Book-Rating'] == 0]
res0Jbooks
# Out:
#             ISBN  Book-Rating
# 2     0002222590          0.0
# 3     0002223589          0.0
# 4     0002224682          0.0
# 7     0006117252          0.0
# 9     0006164587          0.0
# ...          ...          ...
# 5050  B000051ZUT          0.0
# 5051  B0000523SS          0.0
# 5053  B000069F44          0.0
# 5054  B00007MAM9          0.0
# 5057  B00017IWGQ          0.0
#
# [1235 rows x 2 columns]

# %%
res0Jbooksna = avg_rating[avg_rating['Book-Rating'] != 0]
res0Jbooksna
# Out:
#             ISBN  Book-Rating
# 0     000160418X          3.5
# 1     0001841572          2.5
# 5     0002227150          6.0
# 6     0002255081          2.5
# 8     000611962X          3.5
# ...          ...          ...
# 5045  9992003766          5.0
# 5047  9997507002          5.0
# 5052  B00005B4LM          4.0
# 5055  B0000A2U93          3.5
# 5056  B0000AZW79          9.0
#
# [3823 rows x 2 columns]

# %%
sameBooks = df_fix[df_fix['ISBN'].isin(df_ratings['ISBN'])]

# %%
sameBooks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5058 entries, 0 to 12089
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ISBN                 5058 non-null   object
#  1   Book-Title           5058 non-null   object
#  2   Book-Author          5058 non-null   object
#  3   Year-Of-Publication  5058 non-null   object
#  4   Publisher            5058 non-null   object
#  5   Image-URL-S          5058 non-null   object
#  6   Image-URL-M          5058 non-null   object
#  7   Image-URL-L          5058 non-null   object
#  8   Index                5058 non-null   int64
#  9   ID                   5058 non-null   object
#  10  Author               5058 non-null   object
#  11  Summary              5058 non-null   object
#  12  Genres               5058 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 553.2+ KB

# %%
sameBooks = pd.merge(sameBooks, avg_rating, on='ISBN')
sameBooks.head()
# Out:
#          ISBN             Book-Title         Book-Author Year-Of-Publication  \
# 0  0440234743          The Testament        John Grisham                1999
# 1  0345402871               Airframe    Michael Crichton                1997
# 2  0345417623               Timeline    MICHAEL CRICHTON                2000
# 3  0446310786  To Kill a Mockingbird          Harper Lee                1988
# 4  0060168013         Pigs in Heaven  Barbara Kingsolver                1993
#
#                     Publisher  \
# 0                        Dell
# 1            Ballantine Books
# 2            Ballantine Books
# 3  Little Brown &amp; Company
# 4               Harpercollins
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/P/0440234743.01.THUMBZZZ.jpg
# 1  http://images.amazon.com/images/P/0345402871.01.THUMBZZZ.jpg
# 2  http://images.amazon.com/images/P/0345417623.01.THUMBZZZ.jpg
# 3  http://images.amazon.com/images/P/0446310786.01.THUMBZZZ.jpg
# 4  http://images.amazon.com/images/P/0060168013.01.THUMBZZZ.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/P/0440234743.01.MZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0345402871.01.MZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0345417623.01.MZZZZZZZ.jpg
# 3  http://images.amazon.com/images/P/0446310786.01.MZZZZZZZ.jpg
# 4  http://images.amazon.com/images/P/0060168013.01.MZZZZZZZ.jpg
#
#                                                     Image-URL-L  Index  \
# 0  http://images.amazon.com/images/P/0440234743.01.LZZZZZZZ.jpg   2832
# 1  http://images.amazon.com/images/P/0345402871.01.LZZZZZZZ.jpg   1944
# 2  http://images.amazon.com/images/P/0345417623.01.LZZZZZZZ.jpg   2358
# 3  http://images.amazon.com/images/P/0446310786.01.LZZZZZZZ.jpg    309
# 4  http://images.amazon.com/images/P/0060168013.01.LZZZZZZZ.jpg   2884
#
#         ID              Author  \
# 0  1703697        John Grisham
# 1   999996    Michael Crichton
# 2  1298672    Michael Crichton
# 3    73408          Harper Lee
# 4  1761825  Barbara Kingsolver
#
#                                                                                                                                                                                                                                                                                                        Summary  \
# 0   Troy Phelan, an eccentric elderly billionaire, commits suicide minutes after leaving his vast fortune to an illegitimate daughter, Rachel Lane, instead of his six children by three marriages. His reason is revulsion over years of fighting with, and embarrassment from, his family, as well as the...
# 1   The novel opens aboard Hong Kong-based Transpacific Airlines Flight 545, a Norton Aircraft-manufactured N-22 wide-body aircraft, flying from Hong Kong to Denver. An incident occurs on board the plane about a half-hour west of the California coast and the pilot requests an emergency landing at L...
# 2   In the middle of the New Mexico desert, a vacationing couple comes across an ill man wandering miles from town. They find the man, Joe Traub, is a physicist and an employee of a company called ITC. However, ITC's headquarters are mysteriously far from where Traub was found. Traub soon dies of a...
# 3   The book opens with the Finch family's ancestor, Simon Finch, a Cornish Methodist fleeing religious intolerance in England, settling in Alabama, becoming wealthy and, contrary to his religious beliefs, buying several slaves. The main story takes place during three years of the Great Depression ...
# 4   This novel begins two years after the events of Barbara Kingsolver's first novel, The Bean Trees. Taylor and Turtle are visiting the Hoover Dam when Turtle sees a man fall down a spillway. Because of Taylor's unwavering faith that Turtle is telling the truth, a search is conducted and a man's l...
#
#                                  Genres  Book-Rating
# 0         [Thriller, Fiction, Suspense]     3.085308
# 1              [Science Fiction, Novel]     2.845411
# 2  [Science Fiction, Fiction, Suspense]     3.761671
# 3                             [Fiction]     4.920308
# 4                      [Fiction, Novel]     3.709091

# %%
sameBooks.rename(columns={'Book-Rating': 'Avg-Rating'}, inplace=True)

# %%
sameBooks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5058 entries, 0 to 5057
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ISBN                 5058 non-null   object
#  1   Book-Title           5058 non-null   object
#  2   Book-Author          5058 non-null   object
#  3   Year-Of-Publication  5058 non-null   object
#  4   Publisher            5058 non-null   object
#  5   Image-URL-S          5058 non-null   object
#  6   Image-URL-M          5058 non-null   object
#  7   Image-URL-L          5058 non-null   object
#  8   Index                5058 non-null   int64
#  9   ID                   5058 non-null   object
#  10  Author               5058 non-null   object
#  11  Summary              5058 non-null   object
#  12  Genres               5058 non-null   object
#  13  Avg-Rating           5058 non-null   float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 592.7+ KB

# %%
sameBooks = pd.merge(sameBooks, count_rating, on='ISBN')
sameBooks.head()
# Out:
#          ISBN             Book-Title         Book-Author Year-Of-Publication  \
# 0  0440234743          The Testament        John Grisham                1999
# 1  0345402871               Airframe    Michael Crichton                1997
# 2  0345417623               Timeline    MICHAEL CRICHTON                2000
# 3  0446310786  To Kill a Mockingbird          Harper Lee                1988
# 4  0060168013         Pigs in Heaven  Barbara Kingsolver                1993
#
#                     Publisher  \
# 0                        Dell
# 1            Ballantine Books
# 2            Ballantine Books
# 3  Little Brown &amp; Company
# 4               Harpercollins
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/P/0440234743.01.THUMBZZZ.jpg
# 1  http://images.amazon.com/images/P/0345402871.01.THUMBZZZ.jpg
# 2  http://images.amazon.com/images/P/0345417623.01.THUMBZZZ.jpg
# 3  http://images.amazon.com/images/P/0446310786.01.THUMBZZZ.jpg
# 4  http://images.amazon.com/images/P/0060168013.01.THUMBZZZ.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/P/0440234743.01.MZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0345402871.01.MZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0345417623.01.MZZZZZZZ.jpg
# 3  http://images.amazon.com/images/P/0446310786.01.MZZZZZZZ.jpg
# 4  http://images.amazon.com/images/P/0060168013.01.MZZZZZZZ.jpg
#
#                                                     Image-URL-L  Index  \
# 0  http://images.amazon.com/images/P/0440234743.01.LZZZZZZZ.jpg   2832
# 1  http://images.amazon.com/images/P/0345402871.01.LZZZZZZZ.jpg   1944
# 2  http://images.amazon.com/images/P/0345417623.01.LZZZZZZZ.jpg   2358
# 3  http://images.amazon.com/images/P/0446310786.01.LZZZZZZZ.jpg    309
# 4  http://images.amazon.com/images/P/0060168013.01.LZZZZZZZ.jpg   2884
#
#         ID              Author  \
# 0  1703697        John Grisham
# 1   999996    Michael Crichton
# 2  1298672    Michael Crichton
# 3    73408          Harper Lee
# 4  1761825  Barbara Kingsolver
#
#                                                                                                                                                                                                                                                                                                        Summary  \
# 0   Troy Phelan, an eccentric elderly billionaire, commits suicide minutes after leaving his vast fortune to an illegitimate daughter, Rachel Lane, instead of his six children by three marriages. His reason is revulsion over years of fighting with, and embarrassment from, his family, as well as the...
# 1   The novel opens aboard Hong Kong-based Transpacific Airlines Flight 545, a Norton Aircraft-manufactured N-22 wide-body aircraft, flying from Hong Kong to Denver. An incident occurs on board the plane about a half-hour west of the California coast and the pilot requests an emergency landing at L...
# 2   In the middle of the New Mexico desert, a vacationing couple comes across an ill man wandering miles from town. They find the man, Joe Traub, is a physicist and an employee of a company called ITC. However, ITC's headquarters are mysteriously far from where Traub was found. Traub soon dies of a...
# 3   The book opens with the Finch family's ancestor, Simon Finch, a Cornish Methodist fleeing religious intolerance in England, settling in Alabama, becoming wealthy and, contrary to his religious beliefs, buying several slaves. The main story takes place during three years of the Great Depression ...
# 4   This novel begins two years after the events of Barbara Kingsolver's first novel, The Bean Trees. Taylor and Turtle are visiting the Hoover Dam when Turtle sees a man fall down a spillway. Because of Taylor's unwavering faith that Turtle is telling the truth, a search is conducted and a man's l...
#
#                                  Genres  Avg-Rating  Book-Rating
# 0         [Thriller, Fiction, Suspense]    3.085308          422
# 1              [Science Fiction, Novel]    2.845411          207
# 2  [Science Fiction, Fiction, Suspense]    3.761671          407
# 3                             [Fiction]    4.920308          389
# 4                      [Fiction, Novel]    3.709091           55

# %%
sameBooks.rename(columns={'Book-Rating': 'Count-Rating'}, inplace=True)
sameBooks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5058 entries, 0 to 5057
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ISBN                 5058 non-null   object
#  1   Book-Title           5058 non-null   object
#  2   Book-Author          5058 non-null   object
#  3   Year-Of-Publication  5058 non-null   object
#  4   Publisher            5058 non-null   object
#  5   Image-URL-S          5058 non-null   object
#  6   Image-URL-M          5058 non-null   object
#  7   Image-URL-L          5058 non-null   object
#  8   Index                5058 non-null   int64
#  9   ID                   5058 non-null   object
#  10  Author               5058 non-null   object
#  11  Summary              5058 non-null   object
#  12  Genres               5058 non-null   object
#  13  Avg-Rating           5058 non-null   float64
#  14  Count-Rating         5058 non-null   int64
# dtypes: float64(1), int64(2), object(12)
# memory usage: 632.2+ KB

# %%
df_ratings.drop(['Book-Rating_y'], axis=1, inplace=True)

# %%
df_ratings.rename(columns={'Book-Rating_x': 'Book-Rating'}, inplace=True)

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91101 entries, 0 to 91100
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   User-ID      91101 non-null  int64
#  1   ISBN         91101 non-null  object
#  2   Book-Rating  91101 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.8+ MB

# %%
df_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276746  0425115801            0
# 1   277427  0425115801            0
# 2     1660  0425115801            0
# 3     2288  0425115801           10
# 4     4551  0425115801            8

# %%
res = df_ratings[df_ratings['Book-Rating'] != 0]
res
# Out:
#        User-ID        ISBN  Book-Rating
# 3         2288  0425115801           10
# 4         4551  0425115801            8
# 5         4938  0425115801            9
# 6         9856  0425115801            7
# 7        13552  0425115801           10
# ...        ...         ...          ...
# 91079   273976  0786866705            5
# 91083   274186  8466302948            1
# 91084   274199  0140072799            9
# 91094   275825  0689822855            7
# 91095   276560  0689822855            8
#
# [36323 rows x 3 columns]
